# %% [markdown]
# # # Import Modules

# %%
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
import os
import pickle
import numpy as np
from tqdm.notebook import tqdm
import glob
import pandas as pd

from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add
# Out:
# 2023-01-18 12:05:01.265879: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 12:05:02.379924: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:
# 2023-01-18 12:05:02.379999: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.7/lib64:
# 2023-01-18 12:05:02.380006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
BASE_DIR = 'instagram/instagram_data*'
WORKING_DIR = 'working'

# %% [markdown]
# # # Extract Image Features

# %%
# load vgg16 model
model = VGG16()
# restructure the model
model = Model(inputs=model.inputs, outputs=model.layers[-2].output)
#model = VGG16(weights='../input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5')
# summarize
print(model.summary())

#vgg16_accuracy = calc_accuracy(vgg16_model, hot_dog_paths, not_hot_dog_paths)
# Out:
# 2023-01-18 10:53:11.461206: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:11.542237: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:11.542443: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:11.543108: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 10:53:11.543745: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:11.543952: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:11.544144: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:12.691234: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:12.691808: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:12.691996: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 10:53:12.692338: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2579 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
#  fc2 (Dense)                 (None, 4096)              16781312
#
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# extract features from image
features = {}
image_paths = glob.glob(f'{BASE_DIR}/img*/*.jpg')

for img_path in tqdm(image_paths):
    # load the image from file
    # img_path = directory + '/' + img_name
    image = load_img(img_path, target_size=(224, 224))
    # convert image pixels to numpy array
    image = img_to_array(image)
    # reshape data for model
    image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
    # preprocess image for vgg
    image = preprocess_input(image)
    # extract features
    feature = model.predict(image, verbose=0)
    # get image ID
    temp = img_path.split('/')[-1]
    image_id = temp.split('.')[0]
    # store feature
    features[image_id] = feature
# Out:
#   0%|          | 0/34927 [00:00<?, ?it/s]
# 2023-01-18 10:53:20.040355: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8500
# 2023-01-18 10:53:21.288172: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.288259: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.473554: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.473610: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.06GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.631766: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.631857: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.775633: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2023-01-18 10:53:21.775677: W tensorflow/tsl/framework/bfc_allocator.cc:290] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.15GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.

# %%
# store features in pickle
pickle.dump(features, open(os.path.join(WORKING_DIR, 'features.pkl'), 'wb'))

# %%
# load features from pickle
with open(os.path.join(WORKING_DIR, 'features.pkl'), 'rb') as f:
    features = pickle.load(f)

# %%
# Not Needed
for key in list(features.keys()):
    new_key = key.split('/')[-1]
    features[new_key] = features.pop(key)

features['insta23209']
# Out:
# array([[0.       , 2.9443953, 0.       , ..., 0.       , 0.       ,
#         0.       ]], dtype=float32)

# %% [markdown]
# # # Load the Caption Data

# %%
csv_list = glob.glob(f'{BASE_DIR}/captions_csv*.csv')
dataframe = pd.concat(
    [pd.read_csv(csv_list[1]), pd.read_csv(csv_list[0], names = ['Sr No','Image File','Caption'])],
    ignore_index=True
).drop('Sr No', axis=1)

# %%
dataframe['Image'] = dataframe['Image File'].apply(lambda x: x.split('/')[-1])
dataframe['Caption'].fillna('empty', inplace=True)

# %%
dataframe.head()
# Out:
#    Image File                                            Caption   Image
# 0  img/insta1                                              empty  insta1
# 1  img/insta2                                               bye   insta2
# 2  img/insta3  Ok, a few more... sorry I just had so much fun...  insta3
# 3  img/insta4  This was one of my favorite shoots I’ve ever d...  insta4
# 4  img/insta5               Wrapped round my finger like a ring   insta5

# %%
# create mapping of image to captions
mapping = {}
# process lines
for image, cap in dataframe[['Image','Caption']].values:
    image_id, caption = image, cap
    # create list if needed
    if image_id not in mapping:
        mapping[image_id] = []
    # store the caption
    mapping[image_id].append(caption)

# %%
len(mapping)
# Out:
# 34927

# %% [markdown]
# # # Preprocessing Text Data

# %%
def clean(mapping):
    for key, captions in mapping.items():
        for i in range(len(captions)):
            # take one caption at a time
            caption = captions[i]
            # preprocessing steps
            # convert to lowercase
            caption = caption.lower()
            # delete digits, special chars, etc., 
            caption = caption.replace('[^A-Za-z]', '')
            # delete additional spaces
            caption = caption.replace('\s+', ' ')
            # add start and end tags to the caption
            # caption = 'startseq ' + " ".join([word for word in caption.split() if len(word)>1]) + ' endseq'
            caption = 'startseq ' + caption + ' endseq'
            captions[i] = caption

# %%
# before preprocess of text
mapping['insta1000']
# Out:
# ['Them is EVERYTHING tho 🙌 allofme ']

# %%
# preprocess the text
clean(mapping)

# %%
# after preprocess of text
mapping['insta1000']
# Out:
# ['startseq them is everything tho 🙌 allofme  endseq']

# %%
all_captions = []
for key in mapping:
    for caption in mapping[key]:
        all_captions.append(caption)

# %%
len(all_captions)
# Out:
# 34927

# %%
all_captions[:10]
# Out:
# ['startseq empty endseq',
#  'startseq bye  endseq',
#  'startseq ok, a few more... sorry i just had so much fun that day  endseq',
#  'startseq this was one of my favorite shoots i’ve ever done! thank you -a seriously badass woman, for shooting my cover! and thank you to everyone who asked a question for the interview 🤍  endseq',
#  'startseq wrapped round my finger like a ring  endseq',
#  'startseq yesterday was so much fun!! has been such a huge figure in my life. i love her humor, her grace and her heart! check out the interview where i’m gushing over her the whole time!  endseq',
#  'startseq well..  endseq',
#  'startseq it’s officially out! i was a bit embarrassed asking so often for you to stream or buy my album. it felt inauthentic. thank you so much for making something so personal to me be a moment i’ll never forget. all i truly desire is for you all to enjoy the music and spread the love 🦋🌈💫  endseq',
#  'startseq i hope you guys are liking the album! i just want to thank you guys for supporting me and this body of work. it means the world to me.. you have no idea. sorry if it’s been a lot. anyhow here’s some pics from my rare music video. 🤎  endseq',
#  'startseq did it again 🦋 rare  endseq']

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1

# %%
vocab_size
# Out:
# 27750

# %%
# get maximum length of the caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
# Out:
# 404

# %% [markdown]
# # # Train Test Split

# %%
image_ids = list(mapping.keys())
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %%
# startseq girl going into wooden building endseq
#        X                   y
# startseq                   girl
# startseq girl              going
# startseq girl going        into
# ...........
# startseq girl going into wooden building      endseq

# %%
# create data generator to get data in batch (avoids session crash)
def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    # loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            # process each caption
            for caption in captions:
                # encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    
                    # store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield [X1, X2], y
                X1, X2, y = list(), list(), list()
                n = 0

# %% [markdown]
# # # Model Creation

# %%
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,))
fe1 = Dropout(0.4)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
# sequence feature layers
inputs2 = Input(shape=(max_length,))
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(256)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# plot the model
plot_model(model, show_shapes=True)
# Out:
# 2023-01-18 12:05:49.360750: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:49.394202: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:49.394372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:49.394803: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-18 12:05:49.395164: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:49.395316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:49.395441: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:50.031227: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:50.031659: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:50.032030: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-18 12:05:50.032224: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2579 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5

# %%
# train the model
epochs = 40
batch_size = 16
steps = len(train) // batch_size

for i in range(epochs):
    # create data generator
    generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# 2023-01-18 12:06:56.712259: I tensorflow/compiler/xla/service/service.cc:173] XLA service 0x7fdd14013c30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-01-18 12:06:56.712280: I tensorflow/compiler/xla/service/service.cc:181]   StreamExecutor device (0): NVIDIA GeForce GTX 1650, Compute Capability 7.5
# 2023-01-18 12:06:56.728090: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-01-18 12:06:56.992898: I tensorflow/compiler/jit/xla_compilation_cache.cc:477] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#    4/1964 [..............................] - ETA: 28:09 - loss: 9.7006
# 2023-01-18 12:07:11.877358: W tensorflow/tsl/framework/bfc_allocator.cc:479] Allocator (GPU_0_bfc) ran out of memory trying to allocate 184.25MiB (rounded to 193196032)requested by op gradients/cond_grad/If/else/_1/gradients/cond_grad/gradients/cond/TensorArrayUnstack/TensorListFromTensor_grad/TensorListStack_tfg_inlined_gradients/cond_grad/If_1
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2023-01-18 12:07:11.877984: I tensorflow/tsl/framework/bfc_allocator.cc:1034] BFCAllocator dump for GPU_0_bfc
# 2023-01-18 12:07:11.877998: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (256): 	Total Chunks: 7714, Chunks in use: 7714. 1.88MiB allocated for chunks. 1.88MiB in use in bin. 57.0KiB client-requested in use in bin.
# 2023-01-18 12:07:11.878005: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (512): 	Total Chunks: 404, Chunks in use: 404. 202.0KiB allocated for chunks. 202.0KiB in use in bin. 184.2KiB client-requested in use in bin.
# 2023-01-18 12:07:11.878010: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1024): 	Total Chunks: 8, Chunks in use: 8. 9.2KiB allocated for chunks. 9.2KiB in use in bin. 8.1KiB client-requested in use in bin.
# 2023-01-18 12:07:11.878015: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2048): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878021: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4096): 	Total Chunks: 7, Chunks in use: 6. 28.0KiB allocated for chunks. 24.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2023-01-18 12:07:11.878026: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8192): 	Total Chunks: 1, Chunks in use: 0. 11.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878030: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16384): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878034: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878040: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (65536): 	Total Chunks: 3, Chunks in use: 3. 325.5KiB allocated for chunks. 325.5KiB in use in bin. 325.2KiB client-requested in use in bin.
# 2023-01-18 12:07:11.878044: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878050: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (262144): 	Total Chunks: 4026, Chunks in use: 4021. 1.79GiB allocated for chunks. 1.79GiB in use in bin. 1.79GiB client-requested in use in bin.
# 2023-01-18 12:07:11.878055: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (524288): 	Total Chunks: 27, Chunks in use: 27. 22.94MiB allocated for chunks. 22.94MiB in use in bin. 12.58MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878060: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (1048576): 	Total Chunks: 12, Chunks in use: 10. 14.87MiB allocated for chunks. 11.31MiB in use in bin. 10.00MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878065: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (2097152): 	Total Chunks: 1, Chunks in use: 0. 2.37MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878070: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (4194304): 	Total Chunks: 4, Chunks in use: 3. 19.30MiB allocated for chunks. 12.00MiB in use in bin. 12.00MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878074: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (8388608): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878079: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (16777216): 	Total Chunks: 5, Chunks in use: 5. 135.50MiB allocated for chunks. 135.50MiB in use in bin. 135.50MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878084: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (33554432): 	Total Chunks: 2, Chunks in use: 1. 91.27MiB allocated for chunks. 32.16MiB in use in bin. 27.10MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878090: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (67108864): 	Total Chunks: 1, Chunks in use: 1. 87.09MiB allocated for chunks. 87.09MiB in use in bin. 46.06MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878096: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (134217728): 	Total Chunks: 2, Chunks in use: 2. 368.49MiB allocated for chunks. 368.49MiB in use in bin. 368.49MiB client-requested in use in bin.
# 2023-01-18 12:07:11.878101: I tensorflow/tsl/framework/bfc_allocator.cc:1041] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2023-01-18 12:07:11.878106: I tensorflow/tsl/framework/bfc_allocator.cc:1057] Bin for 184.25MiB was 128.00MiB, Chunk State:
# 2023-01-18 12:07:11.878111: I tensorflow/tsl/framework/bfc_allocator.cc:1070] Next region of size 2704932864
# 2023-01-18 12:07:11.878118: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000000 of size 1280 next 1
# 2023-01-18 12:07:11.878123: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000500 of size 256 next 2
# 2023-01-18 12:07:11.878127: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000600 of size 256 next 3
# 2023-01-18 12:07:11.878130: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000700 of size 256 next 5
# 2023-01-18 12:07:11.878134: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000800 of size 256 next 4859
# 2023-01-18 12:07:11.878137: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000900 of size 256 next 3010
# 2023-01-18 12:07:11.878141: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000a00 of size 512 next 6
# 2023-01-18 12:07:11.878147: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000c00 of size 256 next 4
# 2023-01-18 12:07:11.878151: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000d00 of size 256 next 7
# 2023-01-18 12:07:11.878154: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000e00 of size 256 next 12
# 2023-01-18 12:07:11.878157: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e000f00 of size 256 next 10
# 2023-01-18 12:07:11.878160: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001000 of size 256 next 15
# 2023-01-18 12:07:11.878164: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001100 of size 256 next 16
# 2023-01-18 12:07:11.878167: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001200 of size 256 next 21
# 2023-01-18 12:07:11.878170: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001300 of size 256 next 24
# 2023-01-18 12:07:11.878174: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001400 of size 256 next 25
# 2023-01-18 12:07:11.878177: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001500 of size 256 next 17
# 2023-01-18 12:07:11.878181: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001600 of size 256 next 20
# 2023-01-18 12:07:11.878184: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001700 of size 256 next 47
# 2023-01-18 12:07:11.878187: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001800 of size 256 next 28
# 2023-01-18 12:07:11.878190: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001900 of size 256 next 11809
# 2023-01-18 12:07:11.878194: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001a00 of size 256 next 26
# 2023-01-18 12:07:11.878197: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001b00 of size 256 next 29
# 2023-01-18 12:07:11.878200: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001c00 of size 256 next 30
# 2023-01-18 12:07:11.878203: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001d00 of size 256 next 33
# 2023-01-18 12:07:11.878207: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001e00 of size 256 next 34
# 2023-01-18 12:07:11.878210: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e001f00 of size 256 next 35
# 2023-01-18 12:07:11.878213: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002000 of size 256 next 36
# 2023-01-18 12:07:11.878217: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002100 of size 256 next 53
# 2023-01-18 12:07:11.878220: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002200 of size 256 next 22
# 2023-01-18 12:07:11.878224: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002300 of size 512 next 261
# 2023-01-18 12:07:11.878227: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002500 of size 512 next 10119
# 2023-01-18 12:07:11.878230: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002700 of size 512 next 10612
# 2023-01-18 12:07:11.878233: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002900 of size 512 next 7017
# 2023-01-18 12:07:11.878237: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002b00 of size 512 next 11838
# 2023-01-18 12:07:11.878240: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e002d00 of size 1536 next 23
# 2023-01-18 12:07:11.878244: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e003300 of size 4096 next 11
# 2023-01-18 12:07:11.878247: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e004300 of size 4096 next 42
# 2023-01-18 12:07:11.878251: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e005300 of size 754688 next 11861
# 2023-01-18 12:07:11.878255: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e0bd700 of size 478208 next 12209
# 2023-01-18 12:07:11.878259: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e132300 of size 847872 next 18
# 2023-01-18 12:07:11.878262: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e201300 of size 1048576 next 19
# 2023-01-18 12:07:11.878266: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e301300 of size 1835008 next 11810
# 2023-01-18 12:07:11.878269: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e4c1300 of size 1048576 next 77
# 2023-01-18 12:07:11.878273: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e5c1300 of size 1048576 next 41
# 2023-01-18 12:07:11.878276: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc4e6c1300 of size 91325184 next 11803
# 2023-01-18 12:07:11.878282: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc53dd9600 of size 262144 next 49
# 2023-01-18 12:07:11.878286: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc53e19600 of size 262144 next 11795
# 2023-01-18 12:07:11.878289: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc53e59600 of size 1048576 next 11807
# 2023-01-18 12:07:11.878293: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc53f59600 of size 1048576 next 11808
# 2023-01-18 12:07:11.878296: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc54059600 of size 28416000 next 65
# 2023-01-18 12:07:11.878300: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc55b72e00 of size 28416000 next 6394
# 2023-01-18 12:07:11.878304: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5768c600 of size 33719808 next 52
# 2023-01-18 12:07:11.878308: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc596b4c00 of size 256 next 54
# 2023-01-18 12:07:11.878311: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc596b4d00 of size 256 next 55
# 2023-01-18 12:07:11.878314: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc596b4e00 of size 256 next 56
# 2023-01-18 12:07:11.878318: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc596b4f00 of size 256 next 57
# 2023-01-18 12:07:11.878321: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc596b5000 of size 256 next 67
# 2023-01-18 12:07:11.878324: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7fdc596b5100 of size 478208 next 1678
# 2023-01-18 12:07:11.878328: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59729d00 of size 478208 next 5678
# 2023-01-18 12:07:11.878332: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5979e900 of size 478208 next 11827
# 2023-01-18 12:07:11.878335: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59813500 of size 478208 next 8841
# 2023-01-18 12:07:11.878338: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59888100 of size 478208 next 11832
# 2023-01-18 12:07:11.878342: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc598fcd00 of size 478208 next 11858
# 2023-01-18 12:07:11.878345: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59971900 of size 478208 next 11860
# 2023-01-18 12:07:11.878348: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc599e6500 of size 478208 next 11857
# 2023-01-18 12:07:11.878351: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59a5b100 of size 478208 next 11826
# 2023-01-18 12:07:11.878355: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59acfd00 of size 478208 next 11843
# 2023-01-18 12:07:11.878358: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59b44900 of size 478208 next 11841
# 2023-01-18 12:07:11.878362: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7fdc59bb9500 of size 478208 next 12242
# 2023-01-18 12:07:11.878365: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59c2e100 of size 478208 next 5253
# 2023-01-18 12:07:11.878368: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59ca2d00 of size 478208 next 4736
# 2023-01-18 12:07:11.878371: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59d17900 of size 478208 next 12252
# 2023-01-18 12:07:11.878375: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59d8c500 of size 478208 next 11875
# 2023-01-18 12:07:11.878378: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59e01100 of size 478208 next 6180
# 2023-01-18 12:07:11.878381: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59e75d00 of size 478208 next 11840
# 2023-01-18 12:07:11.878384: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59eea900 of size 478208 next 12240
# 2023-01-18 12:07:11.878388: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59f5f500 of size 478208 next 11854
# 2023-01-18 12:07:11.878391: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc59fd4100 of size 478208 next 12239
# 2023-01-18 12:07:11.878395: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a048d00 of size 478208 next 12259
# 2023-01-18 12:07:11.878398: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a0bd900 of size 478208 next 39
# 2023-01-18 12:07:11.878401: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a132500 of size 478208 next 12210
# 2023-01-18 12:07:11.878405: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a1a7100 of size 478208 next 11867
# 2023-01-18 12:07:11.878408: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a21bd00 of size 478208 next 11863
# 2023-01-18 12:07:11.878411: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a290900 of size 478208 next 12229
# 2023-01-18 12:07:11.878415: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a305500 of size 478208 next 12231
# 2023-01-18 12:07:11.878418: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a37a100 of size 478208 next 12198
# 2023-01-18 12:07:11.878421: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a3eed00 of size 478208 next 11865
# 2023-01-18 12:07:11.878424: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a463900 of size 478208 next 11866
# 2023-01-18 12:07:11.878428: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a4d8500 of size 478208 next 11871
# 2023-01-18 12:07:11.878431: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a54d100 of size 478208 next 12238
# 2023-01-18 12:07:11.878434: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a5c1d00 of size 478208 next 12237
# 2023-01-18 12:07:11.878438: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a636900 of size 478208 next 11870
# 2023-01-18 12:07:11.878441: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a6ab500 of size 478208 next 12248
# 2023-01-18 12:07:11.878445: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a720100 of size 478208 next 12235
# 2023-01-18 12:07:11.878448: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a794d00 of size 478208 next 12218
# 2023-01-18 12:07:11.878451: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a809900 of size 478208 next 11873
# 2023-01-18 12:07:11.878455: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a87e500 of size 478208 next 12220
# 2023-01-18 12:07:11.878458: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a8f3100 of size 478208 next 12227
# 2023-01-18 12:07:11.878461: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a967d00 of size 478208 next 11812
# 2023-01-18 12:07:11.878464: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5a9dc900 of size 478208 next 12249
# 2023-01-18 12:07:11.878468: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5aa51500 of size 478208 next 12246
# 2023-01-18 12:07:11.878471: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5aac6100 of size 478208 next 11876
# 2023-01-18 12:07:11.878475: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ab3ad00 of size 478208 next 11877
# 2023-01-18 12:07:11.878478: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5abaf900 of size 478208 next 11878
# 2023-01-18 12:07:11.878481: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ac24500 of size 478208 next 11880
# 2023-01-18 12:07:11.878484: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ac99100 of size 478208 next 11879
# 2023-01-18 12:07:11.878488: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ad0dd00 of size 478208 next 11881
# 2023-01-18 12:07:11.878491: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ad82900 of size 478208 next 11882
# 2023-01-18 12:07:11.878494: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5adf7500 of size 478208 next 11883
# 2023-01-18 12:07:11.878497: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ae6c100 of size 478208 next 11884
# 2023-01-18 12:07:11.878501: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5aee0d00 of size 478208 next 11885
# 2023-01-18 12:07:11.878504: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5af55900 of size 478208 next 11886
# 2023-01-18 12:07:11.878508: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5afca500 of size 478208 next 11887
# 2023-01-18 12:07:11.878511: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b03f100 of size 478208 next 11888
# 2023-01-18 12:07:11.878514: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b0b3d00 of size 478208 next 11889
# 2023-01-18 12:07:11.878518: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b128900 of size 478208 next 11890
# 2023-01-18 12:07:11.878521: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b19d500 of size 478208 next 11891
# 2023-01-18 12:07:11.878524: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b212100 of size 478208 next 11892
# 2023-01-18 12:07:11.878527: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b286d00 of size 478208 next 11893
# 2023-01-18 12:07:11.878531: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b2fb900 of size 478208 next 11894
# 2023-01-18 12:07:11.878534: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b370500 of size 478208 next 11895
# 2023-01-18 12:07:11.878537: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b3e5100 of size 478208 next 11896
# 2023-01-18 12:07:11.878541: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b459d00 of size 478208 next 11897
# 2023-01-18 12:07:11.878545: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b4ce900 of size 478208 next 11898
# 2023-01-18 12:07:11.878548: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b543500 of size 478208 next 11899
# 2023-01-18 12:07:11.878551: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b5b8100 of size 478208 next 11900
# 2023-01-18 12:07:11.878554: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b62cd00 of size 478208 next 11901
# 2023-01-18 12:07:11.878558: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b6a1900 of size 478208 next 11902
# 2023-01-18 12:07:11.878561: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b716500 of size 478208 next 11903
# 2023-01-18 12:07:11.878564: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b78b100 of size 478208 next 11904
# 2023-01-18 12:07:11.878568: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b7ffd00 of size 478208 next 11905
# 2023-01-18 12:07:11.878571: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b874900 of size 478208 next 11906
# 2023-01-18 12:07:11.878574: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b8e9500 of size 478208 next 11907
# 2023-01-18 12:07:11.878577: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b95e100 of size 478208 next 11908
# 2023-01-18 12:07:11.878581: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5b9d2d00 of size 478208 next 11909
# 2023-01-18 12:07:11.878585: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ba47900 of size 478208 next 11910
# 2023-01-18 12:07:11.878588: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5babc500 of size 478208 next 11911
# 2023-01-18 12:07:11.878591: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bb31100 of size 478208 next 11912
# 2023-01-18 12:07:11.878595: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bba5d00 of size 478208 next 11913
# 2023-01-18 12:07:11.878598: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bc1a900 of size 478208 next 11914
# 2023-01-18 12:07:11.878601: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bc8f500 of size 478208 next 11915
# 2023-01-18 12:07:11.878604: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bd04100 of size 478208 next 11916
# 2023-01-18 12:07:11.878608: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bd78d00 of size 478208 next 11917
# 2023-01-18 12:07:11.878611: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bded900 of size 478208 next 11918
# 2023-01-18 12:07:11.878615: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5be62500 of size 478208 next 11919
# 2023-01-18 12:07:11.878618: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bed7100 of size 478208 next 11920
# 2023-01-18 12:07:11.878621: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bf4bd00 of size 478208 next 11921
# 2023-01-18 12:07:11.878625: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5bfc0900 of size 478208 next 11923
# 2023-01-18 12:07:11.878628: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c035500 of size 478208 next 11922
# 2023-01-18 12:07:11.878631: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c0aa100 of size 478208 next 11924
# 2023-01-18 12:07:11.878635: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c11ed00 of size 478208 next 11925
# 2023-01-18 12:07:11.878638: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c193900 of size 478208 next 11926
# 2023-01-18 12:07:11.878642: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c208500 of size 478208 next 11927
# 2023-01-18 12:07:11.878645: I tensorflow/tsl/framework/bfc_allocator.cc:1090] Free  at 7fdc5c27d100 of size 478208 next 11928
# 2023-01-18 12:07:11.878648: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c2f1d00 of size 478208 next 11929
# 2023-01-18 12:07:11.878652: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c366900 of size 478208 next 11930
# 2023-01-18 12:07:11.878655: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c3db500 of size 478208 next 11931
# 2023-01-18 12:07:11.878658: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c450100 of size 478208 next 11932
# 2023-01-18 12:07:11.878661: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c4c4d00 of size 478208 next 11933
# 2023-01-18 12:07:11.878665: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c539900 of size 478208 next 11934
# 2023-01-18 12:07:11.878669: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c5ae500 of size 478208 next 11935
# 2023-01-18 12:07:11.878672: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c623100 of size 478208 next 11936
# 2023-01-18 12:07:11.878675: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c697d00 of size 478208 next 11937
# 2023-01-18 12:07:11.878679: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c70c900 of size 478208 next 11938
# 2023-01-18 12:07:11.878682: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c781500 of size 478208 next 11940
# 2023-01-18 12:07:11.878685: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c7f6100 of size 478208 next 11939
# 2023-01-18 12:07:11.878688: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c86ad00 of size 478208 next 6852
# 2023-01-18 12:07:11.878692: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c8df900 of size 478208 next 11942
# 2023-01-18 12:07:11.878696: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c954500 of size 478208 next 11941
# 2023-01-18 12:07:11.878701: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5c9c9100 of size 478208 next 11943
# 2023-01-18 12:07:11.878708: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ca3dd00 of size 478208 next 11944
# 2023-01-18 12:07:11.878713: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cab2900 of size 478208 next 11945
# 2023-01-18 12:07:11.878720: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cb27500 of size 478208 next 11946
# 2023-01-18 12:07:11.878725: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cb9c100 of size 478208 next 11947
# 2023-01-18 12:07:11.878733: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cc10d00 of size 478208 next 11948
# 2023-01-18 12:07:11.878740: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cc85900 of size 478208 next 11949
# 2023-01-18 12:07:11.878747: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ccfa500 of size 478208 next 11950
# 2023-01-18 12:07:11.878755: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cd6f100 of size 478208 next 11951
# 2023-01-18 12:07:11.878760: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cde3d00 of size 478208 next 11952
# 2023-01-18 12:07:11.878763: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ce58900 of size 478208 next 11953
# 2023-01-18 12:07:11.878766: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cecd500 of size 478208 next 11954
# 2023-01-18 12:07:11.878769: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cf42100 of size 478208 next 11955
# 2023-01-18 12:07:11.878773: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5cfb6d00 of size 478208 next 11956
# 2023-01-18 12:07:11.878776: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d02b900 of size 478208 next 11957
# 2023-01-18 12:07:11.878779: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d0a0500 of size 478208 next 11958
# 2023-01-18 12:07:11.878782: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d115100 of size 478208 next 11959
# 2023-01-18 12:07:11.878786: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d189d00 of size 478208 next 11960
# 2023-01-18 12:07:11.878789: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d1fe900 of size 478208 next 11961
# 2023-01-18 12:07:11.878793: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d273500 of size 478208 next 11962
# 2023-01-18 12:07:11.878796: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d2e8100 of size 478208 next 11963
# 2023-01-18 12:07:11.878800: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d35cd00 of size 478208 next 11964
# 2023-01-18 12:07:11.878803: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d3d1900 of size 478208 next 11965
# 2023-01-18 12:07:11.878806: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d446500 of size 478208 next 11966
# 2023-01-18 12:07:11.878809: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d4bb100 of size 478208 next 11967
# 2023-01-18 12:07:11.878813: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d52fd00 of size 478208 next 11968
# 2023-01-18 12:07:11.878816: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d5a4900 of size 478208 next 11969
# 2023-01-18 12:07:11.878819: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d619500 of size 478208 next 11970
# 2023-01-18 12:07:11.878822: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d68e100 of size 478208 next 11971
# 2023-01-18 12:07:11.878825: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d702d00 of size 478208 next 11972
# 2023-01-18 12:07:11.878829: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d777900 of size 478208 next 11973
# 2023-01-18 12:07:11.878832: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d7ec500 of size 478208 next 11974
# 2023-01-18 12:07:11.878836: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d861100 of size 478208 next 11975
# 2023-01-18 12:07:11.878839: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d8d5d00 of size 478208 next 11976
# 2023-01-18 12:07:11.878845: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d94a900 of size 478208 next 11977
# 2023-01-18 12:07:11.878848: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5d9bf500 of size 478208 next 11978
# 2023-01-18 12:07:11.878851: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5da34100 of size 478208 next 11979
# 2023-01-18 12:07:11.878855: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5daa8d00 of size 478208 next 11980
# 2023-01-18 12:07:11.878858: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5db1d900 of size 478208 next 11981
# 2023-01-18 12:07:11.878861: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5db92500 of size 478208 next 11982
# 2023-01-18 12:07:11.878864: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dc07100 of size 478208 next 11983
# 2023-01-18 12:07:11.878868: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dc7bd00 of size 478208 next 11984
# 2023-01-18 12:07:11.878871: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dcf0900 of size 478208 next 11985
# 2023-01-18 12:07:11.878874: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dd65500 of size 478208 next 11986
# 2023-01-18 12:07:11.878877: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ddda100 of size 478208 next 11987
# 2023-01-18 12:07:11.878881: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5de4ed00 of size 478208 next 11988
# 2023-01-18 12:07:11.878884: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dec3900 of size 478208 next 11989
# 2023-01-18 12:07:11.878888: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5df38500 of size 478208 next 11990
# 2023-01-18 12:07:11.878891: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5dfad100 of size 478208 next 11991
# 2023-01-18 12:07:11.878894: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e021d00 of size 478208 next 11992
# 2023-01-18 12:07:11.878897: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e096900 of size 478208 next 11993
# 2023-01-18 12:07:11.878901: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e10b500 of size 478208 next 11995
# 2023-01-18 12:07:11.878904: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e180100 of size 478208 next 11994
# 2023-01-18 12:07:11.878908: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e1f4d00 of size 641536 next 66
# 2023-01-18 12:07:11.878911: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e291700 of size 256 next 70
# 2023-01-18 12:07:11.878915: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e291800 of size 256 next 74
# 2023-01-18 12:07:11.878918: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e291900 of size 4096 next 75
# 2023-01-18 12:07:11.878921: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e292900 of size 478208 next 9170
# 2023-01-18 12:07:11.878924: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e307500 of size 478208 next 385
# 2023-01-18 12:07:11.878928: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e37c100 of size 478208 next 9329
# 2023-01-18 12:07:11.878931: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e3f0d00 of size 478208 next 4448
# 2023-01-18 12:07:11.878934: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e465900 of size 478208 next 10204
# 2023-01-18 12:07:11.878938: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e4da500 of size 478208 next 6255
# 2023-01-18 12:07:11.878941: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e54f100 of size 478208 next 207
# 2023-01-18 12:07:11.878944: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e5c3d00 of size 478208 next 11133
# 2023-01-18 12:07:11.878947: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e638900 of size 478208 next 9703
# 2023-01-18 12:07:11.878951: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e6ad500 of size 478208 next 8959
# 2023-01-18 12:07:11.878955: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e722100 of size 478208 next 4085
# 2023-01-18 12:07:11.878958: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e796d00 of size 478208 next 1008
# 2023-01-18 12:07:11.878961: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e80b900 of size 478208 next 4311
# 2023-01-18 12:07:11.878964: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e880500 of size 478208 next 3112
# 2023-01-18 12:07:11.878967: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e8f5100 of size 478208 next 11780
# 2023-01-18 12:07:11.878971: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e969d00 of size 478208 next 7300
# 2023-01-18 12:07:11.878974: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5e9de900 of size 478208 next 5161
# 2023-01-18 12:07:11.878977: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ea53500 of size 478208 next 27
# 2023-01-18 12:07:11.878981: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5eac8100 of size 478208 next 2347
# 2023-01-18 12:07:11.878984: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5eb3cd00 of size 478208 next 5891
# 2023-01-18 12:07:11.878988: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ebb1900 of size 478208 next 11582
# 2023-01-18 12:07:11.878991: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ec26500 of size 478208 next 11601
# 2023-01-18 12:07:11.878994: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ec9b100 of size 478208 next 3611
# 2023-01-18 12:07:11.878997: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ed0fd00 of size 478208 next 1469
# 2023-01-18 12:07:11.879001: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ed84900 of size 478208 next 4126
# 2023-01-18 12:07:11.879004: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5edf9500 of size 478208 next 2061
# 2023-01-18 12:07:11.879007: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ee6e100 of size 478208 next 4367
# 2023-01-18 12:07:11.879011: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5eee2d00 of size 478208 next 744
# 2023-01-18 12:07:11.879014: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ef57900 of size 478208 next 5325
# 2023-01-18 12:07:11.879018: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5efcc500 of size 478208 next 4330
# 2023-01-18 12:07:11.879021: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f041100 of size 478208 next 9185
# 2023-01-18 12:07:11.879024: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f0b5d00 of size 478208 next 8123
# 2023-01-18 12:07:11.879028: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f12a900 of size 478208 next 3416
# 2023-01-18 12:07:11.879031: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f19f500 of size 478208 next 2016
# 2023-01-18 12:07:11.879035: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f214100 of size 478208 next 5397
# 2023-01-18 12:07:11.879038: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f288d00 of size 478208 next 3783
# 2023-01-18 12:07:11.879042: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f2fd900 of size 478208 next 8002
# 2023-01-18 12:07:11.879045: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f372500 of size 478208 next 1491
# 2023-01-18 12:07:11.879048: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f3e7100 of size 478208 next 6671
# 2023-01-18 12:07:11.879051: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f45bd00 of size 478208 next 9449
# 2023-01-18 12:07:11.879055: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f4d0900 of size 478208 next 406
# 2023-01-18 12:07:11.879058: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f545500 of size 478208 next 4983
# 2023-01-18 12:07:11.879062: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f5ba100 of size 478208 next 9233
# 2023-01-18 12:07:11.879065: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f62ed00 of size 478208 next 11656
# 2023-01-18 12:07:11.879068: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f6a3900 of size 478208 next 11034
# 2023-01-18 12:07:11.879072: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f718500 of size 478208 next 3501
# 2023-01-18 12:07:11.879075: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f78d100 of size 478208 next 11704
# 2023-01-18 12:07:11.879078: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f801d00 of size 478208 next 6974
# 2023-01-18 12:07:11.879081: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f876900 of size 478208 next 6479
# 2023-01-18 12:07:11.879085: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f8eb500 of size 478208 next 10742
# 2023-01-18 12:07:11.879088: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f960100 of size 478208 next 3800
# 2023-01-18 12:07:11.879091: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5f9d4d00 of size 478208 next 256
# 2023-01-18 12:07:11.879095: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fa49900 of size 478208 next 689
# 2023-01-18 12:07:11.879098: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fabe500 of size 478208 next 10127
# 2023-01-18 12:07:11.879101: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fb33100 of size 478208 next 10310
# 2023-01-18 12:07:11.879105: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fba7d00 of size 478208 next 1836
# 2023-01-18 12:07:11.879108: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fc1c900 of size 478208 next 7057
# 2023-01-18 12:07:11.879111: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fc91500 of size 478208 next 8829
# 2023-01-18 12:07:11.879114: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fd06100 of size 478208 next 7006
# 2023-01-18 12:07:11.879118: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fd7ad00 of size 478208 next 5474
# 2023-01-18 12:07:11.879121: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fdef900 of size 478208 next 6040
# 2023-01-18 12:07:11.879125: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fe64500 of size 478208 next 2596
# 2023-01-18 12:07:11.879128: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5fed9100 of size 478208 next 8055
# 2023-01-18 12:07:11.879132: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ff4dd00 of size 478208 next 5407
# 2023-01-18 12:07:11.879135: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc5ffc2900 of size 478208 next 7475
# 2023-01-18 12:07:11.879138: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60037500 of size 478208 next 3674
# 2023-01-18 12:07:11.879141: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc600ac100 of size 478208 next 1879
# 2023-01-18 12:07:11.879144: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60120d00 of size 478208 next 7564
# 2023-01-18 12:07:11.879148: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60195900 of size 478208 next 899
# 2023-01-18 12:07:11.879151: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6020a500 of size 478208 next 10528
# 2023-01-18 12:07:11.879154: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6027f100 of size 478208 next 2389
# 2023-01-18 12:07:11.879157: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc602f3d00 of size 478208 next 7390
# 2023-01-18 12:07:11.879161: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60368900 of size 478208 next 3519
# 2023-01-18 12:07:11.879164: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc603dd500 of size 478208 next 3956
# 2023-01-18 12:07:11.879168: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60452100 of size 478208 next 8893
# 2023-01-18 12:07:11.879171: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc604c6d00 of size 478208 next 7520
# 2023-01-18 12:07:11.879174: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6053b900 of size 478208 next 10155
# 2023-01-18 12:07:11.879178: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc605b0500 of size 478208 next 2201
# 2023-01-18 12:07:11.879181: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60625100 of size 478208 next 5566
# 2023-01-18 12:07:11.879184: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60699d00 of size 478208 next 7762
# 2023-01-18 12:07:11.879187: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6070e900 of size 478208 next 5766
# 2023-01-18 12:07:11.879191: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60783500 of size 478208 next 325
# 2023-01-18 12:07:11.879194: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc607f8100 of size 478208 next 1982
# 2023-01-18 12:07:11.879198: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6086cd00 of size 478208 next 3505
# 2023-01-18 12:07:11.879201: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc608e1900 of size 478208 next 5889
# 2023-01-18 12:07:11.879204: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60956500 of size 478208 next 2670
# 2023-01-18 12:07:11.879207: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc609cb100 of size 478208 next 3208
# 2023-01-18 12:07:11.879210: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60a3fd00 of size 478208 next 11088
# 2023-01-18 12:07:11.879214: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60ab4900 of size 256 next 11103
# 2023-01-18 12:07:11.879217: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60ab4a00 of size 256 next 5975
# 2023-01-18 12:07:11.879221: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60ab4b00 of size 256 next 11373
# 2023-01-18 12:07:11.879224: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60ab4c00 of size 478208 next 6065
# 2023-01-18 12:07:11.879227: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60b29800 of size 256 next 2815
# 2023-01-18 12:07:11.879231: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60b29900 of size 256 next 10819
# 2023-01-18 12:07:11.879234: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60b29a00 of size 256 next 4827
# 2023-01-18 12:07:11.879237: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60b29b00 of size 954880 next 11383
# 2023-01-18 12:07:11.879241: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60c12d00 of size 478208 next 2342
# 2023-01-18 12:07:11.879244: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60c87900 of size 478208 next 2333
# 2023-01-18 12:07:11.879247: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60cfc500 of size 478208 next 7165
# 2023-01-18 12:07:11.879251: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60d71100 of size 478208 next 6206
# 2023-01-18 12:07:11.879254: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60de5d00 of size 478208 next 2392
# 2023-01-18 12:07:11.879258: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60e5a900 of size 478208 next 187
# 2023-01-18 12:07:11.879261: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60ecf500 of size 478208 next 4502
# 2023-01-18 12:07:11.879264: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60f44100 of size 478208 next 1484
# 2023-01-18 12:07:11.879268: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc60fb8d00 of size 478208 next 1445
# 2023-01-18 12:07:11.879271: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc6102d900 of size 478208 next 299
# 2023-01-18 12:07:11.879274: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdc610a2500 of size 478208 next 10354
# ...
# 2023-01-18 12:07:11.923154: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced4a3200 of size 478208 next 10095
# 2023-01-18 12:07:11.923157: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced517e00 of size 478208 next 10518
# 2023-01-18 12:07:11.923160: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced58ca00 of size 478208 next 787
# 2023-01-18 12:07:11.923163: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced601600 of size 478208 next 3992
# 2023-01-18 12:07:11.923166: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced676200 of size 478208 next 5865
# 2023-01-18 12:07:11.923169: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced6eae00 of size 478208 next 11051
# 2023-01-18 12:07:11.923171: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced75fa00 of size 478208 next 2931
# 2023-01-18 12:07:11.923174: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced7d4600 of size 478208 next 9121
# 2023-01-18 12:07:11.923177: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced849200 of size 478208 next 2817
# 2023-01-18 12:07:11.923180: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced8bde00 of size 478208 next 5995
# 2023-01-18 12:07:11.923183: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced932a00 of size 478208 next 1610
# 2023-01-18 12:07:11.923186: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdced9a7600 of size 478208 next 1660
# 2023-01-18 12:07:11.923189: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceda1c200 of size 478208 next 8577
# 2023-01-18 12:07:11.923192: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceda90e00 of size 478208 next 2224
# 2023-01-18 12:07:11.923195: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedb05a00 of size 478208 next 8133
# 2023-01-18 12:07:11.923198: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedb7a600 of size 478208 next 11083
# 2023-01-18 12:07:11.923203: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedbef200 of size 478208 next 9147
# 2023-01-18 12:07:11.923208: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedc63e00 of size 478208 next 1182
# 2023-01-18 12:07:11.923212: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedcd8a00 of size 478208 next 751
# 2023-01-18 12:07:11.923215: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedd4d600 of size 478208 next 779
# 2023-01-18 12:07:11.923218: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceddc2200 of size 478208 next 2234
# 2023-01-18 12:07:11.923221: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcede36e00 of size 478208 next 7229
# 2023-01-18 12:07:11.923224: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedeaba00 of size 478208 next 1768
# 2023-01-18 12:07:11.923227: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedf20600 of size 478208 next 11483
# 2023-01-18 12:07:11.923230: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcedf95200 of size 478208 next 8598
# 2023-01-18 12:07:11.923233: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee009e00 of size 478208 next 10659
# 2023-01-18 12:07:11.923238: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee07ea00 of size 478208 next 444
# 2023-01-18 12:07:11.923243: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee0f3600 of size 478208 next 9295
# 2023-01-18 12:07:11.923249: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee168200 of size 478208 next 952
# 2023-01-18 12:07:11.923254: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee1dce00 of size 478208 next 9031
# 2023-01-18 12:07:11.923258: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee251a00 of size 478208 next 8897
# 2023-01-18 12:07:11.923262: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee2c6600 of size 478208 next 2890
# 2023-01-18 12:07:11.923267: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee33b200 of size 478208 next 8717
# 2023-01-18 12:07:11.923273: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee3afe00 of size 478208 next 81
# 2023-01-18 12:07:11.923280: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee424a00 of size 478208 next 7966
# 2023-01-18 12:07:11.923283: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee499600 of size 478208 next 4696
# 2023-01-18 12:07:11.923286: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee50e200 of size 478208 next 7650
# 2023-01-18 12:07:11.923290: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee582e00 of size 478208 next 5189
# 2023-01-18 12:07:11.923293: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee5f7a00 of size 478208 next 8759
# 2023-01-18 12:07:11.923295: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee66c600 of size 478208 next 5336
# 2023-01-18 12:07:11.923298: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee6e1200 of size 478208 next 9444
# 2023-01-18 12:07:11.923301: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee755e00 of size 478208 next 5668
# 2023-01-18 12:07:11.923304: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee7caa00 of size 478208 next 11406
# 2023-01-18 12:07:11.923307: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee83f600 of size 478208 next 5069
# 2023-01-18 12:07:11.923310: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee8b4200 of size 478208 next 6308
# 2023-01-18 12:07:11.923313: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee928e00 of size 478208 next 10384
# 2023-01-18 12:07:11.923316: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcee99da00 of size 478208 next 5616
# 2023-01-18 12:07:11.923320: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceea12600 of size 478208 next 8059
# 2023-01-18 12:07:11.923323: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceea87200 of size 478208 next 5402
# 2023-01-18 12:07:11.923326: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceeafbe00 of size 478208 next 404
# 2023-01-18 12:07:11.923328: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceeb70a00 of size 478208 next 2964
# 2023-01-18 12:07:11.923331: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceebe5600 of size 478208 next 1825
# 2023-01-18 12:07:11.923334: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceec5a200 of size 478208 next 10209
# 2023-01-18 12:07:11.923338: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceeccee00 of size 478208 next 5236
# 2023-01-18 12:07:11.923341: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceed43a00 of size 478208 next 5095
# 2023-01-18 12:07:11.923344: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceedb8600 of size 478208 next 5192
# 2023-01-18 12:07:11.923347: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceee2d200 of size 478208 next 5573
# 2023-01-18 12:07:11.923350: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceeea1e00 of size 478208 next 3330
# 2023-01-18 12:07:11.923354: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceef16a00 of size 478208 next 10124
# 2023-01-18 12:07:11.923361: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdceef8b600 of size 478208 next 5083
# 2023-01-18 12:07:11.923365: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef000200 of size 478208 next 5747
# 2023-01-18 12:07:11.923368: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef074e00 of size 478208 next 6783
# 2023-01-18 12:07:11.923371: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef0e9a00 of size 478208 next 9965
# 2023-01-18 12:07:11.923374: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef15e600 of size 478208 next 4754
# 2023-01-18 12:07:11.923377: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef1d3200 of size 478208 next 9399
# 2023-01-18 12:07:11.923380: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef247e00 of size 478208 next 5859
# 2023-01-18 12:07:11.923384: I tensorflow/tsl/framework/bfc_allocator.cc:1090] InUse at 7fdcef2bca00 of size 931328 next 18446744073709551615
# 2023-01-18 12:07:11.923388: I tensorflow/tsl/framework/bfc_allocator.cc:1095]      Summary of in-use Chunks by size:
# 2023-01-18 12:07:11.923398: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 7714 Chunks of size 256 totalling 1.88MiB
# 2023-01-18 12:07:11.923405: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 404 Chunks of size 512 totalling 202.0KiB
# 2023-01-18 12:07:11.923410: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 5 Chunks of size 1024 totalling 5.0KiB
# 2023-01-18 12:07:11.923414: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1280 totalling 1.2KiB
# 2023-01-18 12:07:11.923417: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 1536 totalling 3.0KiB
# 2023-01-18 12:07:11.923421: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 6 Chunks of size 4096 totalling 24.0KiB
# 2023-01-18 12:07:11.923425: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 111104 totalling 325.5KiB
# 2023-01-18 12:07:11.923428: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 262144 totalling 512.0KiB
# 2023-01-18 12:07:11.923432: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 312320 totalling 305.0KiB
# 2023-01-18 12:07:11.923436: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 4018 Chunks of size 478208 totalling 1.79GiB
# 2023-01-18 12:07:11.923440: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 641536 totalling 626.5KiB
# 2023-01-18 12:07:11.923444: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 662528 totalling 647.0KiB
# 2023-01-18 12:07:11.923447: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 704000 totalling 687.5KiB
# 2023-01-18 12:07:11.923451: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 751616 totalling 734.0KiB
# 2023-01-18 12:07:11.923454: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 754688 totalling 1.44MiB
# 2023-01-18 12:07:11.923458: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 826368 totalling 807.0KiB
# 2023-01-18 12:07:11.923461: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 847872 totalling 828.0KiB
# 2023-01-18 12:07:11.923466: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 931328 totalling 909.5KiB
# 2023-01-18 12:07:11.923469: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 4 Chunks of size 953856 totalling 3.64MiB
# 2023-01-18 12:07:11.923472: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 954112 totalling 931.8KiB
# 2023-01-18 12:07:11.923476: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 4 Chunks of size 954624 totalling 3.64MiB
# 2023-01-18 12:07:11.923479: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 5 Chunks of size 954880 totalling 4.55MiB
# 2023-01-18 12:07:11.923483: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 955136 totalling 932.8KiB
# 2023-01-18 12:07:11.923486: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 955648 totalling 933.2KiB
# 2023-01-18 12:07:11.923490: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 955904 totalling 1.82MiB
# 2023-01-18 12:07:11.923493: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 7 Chunks of size 1048576 totalling 7.00MiB
# 2023-01-18 12:07:11.923496: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1249280 totalling 1.19MiB
# 2023-01-18 12:07:11.923500: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1434624 totalling 1.37MiB
# 2023-01-18 12:07:11.923504: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 1835008 totalling 1.75MiB
# 2023-01-18 12:07:11.923508: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 3 Chunks of size 4194304 totalling 12.00MiB
# 2023-01-18 12:07:11.923516: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 5 Chunks of size 28416000 totalling 135.50MiB
# 2023-01-18 12:07:11.923522: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 33719808 totalling 32.16MiB
# 2023-01-18 12:07:11.923526: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 1 Chunks of size 91325184 totalling 87.09MiB
# 2023-01-18 12:07:11.923530: I tensorflow/tsl/framework/bfc_allocator.cc:1098] 2 Chunks of size 193196032 totalling 368.49MiB
# 2023-01-18 12:07:11.923534: I tensorflow/tsl/framework/bfc_allocator.cc:1102] Sum Total of in-use chunks: 2.45GiB
# 2023-01-18 12:07:11.923538: I tensorflow/tsl/framework/bfc_allocator.cc:1104] total_region_allocated_bytes_: 2704932864 memory_limit_: 2704932864 available bytes: 0 curr_region_allocation_bytes_: 5409865728
# 2023-01-18 12:07:11.923544: I tensorflow/tsl/framework/bfc_allocator.cc:1110] Stats:
# Limit:                      2704932864
# InUse:                      2626843904
# MaxInUse:                   2704932864
# NumAllocs:                      107729
# MaxAllocSize:                255308544
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2023-01-18 12:07:11.924368: W tensorflow/tsl/framework/bfc_allocator.cc:492] *****************************************************_**********************************************
# 2023-01-18 12:07:11.924413: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at list_kernels.h:222 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[404,467,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[26], line 10
#       8 generator = data_generator(train, mapping, features, tokenizer, max_length, vocab_size, batch_size)
#       9 # fit for one epoch
# ---> 10 model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
#
# File ~/Desktop/PProject/FuseClassroom/project/fuseProject/lib/python3.10/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/Desktop/PProject/FuseClassroom/project/fuseProject/lib/python3.10/site-packages/tensorflow/python/eager/execute.py:52, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50 try:
#      51   ctx.ensure_initialized()
# ---> 52   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                       inputs, attrs, num_outputs)
#      54 except core._NotOkStatusException as e:
#      55   if name is not None:
#
# ResourceExhaustedError: Graph execution error:
#
# OOM when allocating tensor with shape[404,467,256] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[{{node gradients/cond_grad/gradients/cond/TensorArrayUnstack/TensorListFromTensor_grad/TensorListStack_tfg_inlined_gradients/cond_grad/If_1}}]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#
# 	 [[PartitionedCall]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_7825]

# %%
# save the model
model.save(WORKING_DIR+'/best_model.h5')

# %% [markdown]
# # # Generate Captions for the Image

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None

# %%
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    # add start tag for generation process
    in_text = 'startseq'
    # iterate over the max length of sequence
    for i in range(max_length):
        # encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        # pad the sequence
        sequence = pad_sequences([sequence], max_length)
        # predict next word
        yhat = model.predict([image, sequence], verbose=0)
        # get index with high probability
        yhat = np.argmax(yhat)
        # convert index to word
        word = idx_to_word(yhat, tokenizer)
        # stop if word not found
        if word is None:
            break
        # append word as input for generating next word
        in_text += " " + word
        # stop if we reach end tag
        if word == 'endseq':
            break
      
    return in_text

# %%
from nltk.translate.bleu_score import corpus_bleu
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    # get actual caption
    captions = mapping[key]
    # predict the caption for image
    y_pred = predict_caption(model, features[key], tokenizer, max_length) 
    # split into words
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    # append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
    
# calcuate BLEU score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
# Out:
#   0%|          | 0/3493 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 9
#       7 captions = mapping[key]
#       8 # predict the caption for image
# ----> 9 y_pred = predict_caption(model, features[key], tokenizer, max_length)
#      10 # split into words
#      11 actual_captions = [caption.split() for caption in captions]
#
# NameError: name 'predict_caption' is not defined

# %% [markdown]
# # # Visualize the Results

# %%
from PIL import Image
import matplotlib.pyplot as plt
def generate_caption(image_name):
    # load the image
    # image_name = "1001773457_577c3a7d70.jpg"
    image_id = image_name.split('.')[0]
    img_path = os.path.join(BASE_DIR, "Images", image_name)
    image = Image.open(img_path)
    captions = mapping[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, features[image_id], tokenizer, max_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    plt.imshow(image)

# %%
generate_caption("1001773457_577c3a7d70.jpg")

# %%
generate_caption("1002674143_1b742ab4b8.jpg")

# %%
generate_caption("101669240_b2d3e7f17b.jpg")
